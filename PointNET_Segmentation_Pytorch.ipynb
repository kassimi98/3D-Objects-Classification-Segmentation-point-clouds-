# %%
# !nvidia-smi
# Out:
# Thu Jul  1 10:54:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/fxia22/pointnet.pytorch
# %cd pointnet.pytorch
# Out:
# Cloning into 'pointnet.pytorch'...
# remote: Enumerating objects: 209, done.
# remote: Total 209 (delta 0), reused 0 (delta 0), pack-reused 209
# Receiving objects: 100% (209/209), 228.47 KiB | 25.38 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# /content/pointnet.pytorch

# %%
pip install -e .
# Out:
# Obtaining file:///content/pointnet.pytorch
# ...
#   Running setup.py develop for pointnet
# ...

# %%
# %cd /content/pointnet.pytorch
# Out:
# /content/pointnet.pytorch

# %%
# %%bash
# SCRIPT=`realpath $0`
# SCRIPTPATH=`dirname $SCRIPT`
# echo $SCRIPTPATH
#
# g++ -std=c++11 $SCRIPTPATH/../utils/render_balls_so.cpp -o $SCRIPTPATH/../utils/render_balls_so.so -shared -fPIC -O2 -D_GLIBCXX_USE_CXX11_ABI=0
# Out:
# /content/pointnet.pytorch
# g++: error: /content/pointnet.pytorch/../utils/render_balls_so.cpp: No such file or directory
# g++: fatal error: no input files
# compilation terminated.

# %%
# %%bash
#
# SCRIPT=`realpath $0`
# SCRIPTPATH=`dirname $SCRIPT`
# cd $SCRIPTPATH/..
# wget https://shapenet.cs.stanford.edu/ericyi/shapenetcore_partanno_segmentation_benchmark_v0.zip --no-check-certificate
# unzip shapenetcore_partanno_segmentation_benchmark_v0.zip
# rm shapenetcore_partanno_segmentation_benchmark_v0.zip
# cd -
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 400850K .......... .......... .......... .......... .......... 61% 1.86M 98s
# 400900K .......... .......... .......... .......... .......... 61% 1.87M 98s
# 400950K .......... .......... .......... .......... .......... 61% 1.87M 98s
# 401000K .......... .......... .......... .......... .......... 61% 1.85M 98s
# 401050K .......... .......... .......... .......... .......... 61% 1.88M 98s
# 401100K .......... .......... .......... .......... .......... 61% 1.86M 98s
# 401150K .......... .......... .......... .......... .......... 61% 1.87M 98s
# 401200K .......... .......... .......... .......... .......... 61% 1.85M 98s
# 401250K .......... .......... .......... .......... .......... 61% 1.87M 98s
# 401300K .......... .......... .......... .......... .......... 61% 97.5M 98s
# 401350K .......... .......... .......... .......... .......... 61% 1.87M 98s
# ...

# %%
# %cd /content/pointnet.pytorch/utils
# Out:
# /content/pointnet.pytorch/utils

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Rocket' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Rocket', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  6367
# {'Rocket': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 3
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Rocket': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Pistol' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Pistol', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  3503
# {'Pistol': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 3
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Pistol': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Airplane' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Airplane', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  2301
# {'Airplane': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Airplane': 0}
# ...

# %%
# !python train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=150  --class_choice='Knife' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Knife', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=150, outf='seg', workers=4)
# Random Seed:  3007
# {'Knife': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 2
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Knife': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0  --nepoch=250  --class_choice='Skateboard' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Skateboard', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=250, outf='seg', workers=4)
# Random Seed:  8156
# {'Skateboard': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 3
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Skateboard': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Chair' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Chair', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  4941
# {'Chair': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Chair': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Bag' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Bag', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  5864
# {'Bag': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 2
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Bag': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=80  --class_choice='Car' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Car', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=80, outf='seg', workers=4)
# Random Seed:  8518
# {'Car': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Car': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=150  --class_choice='Earphone' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Earphone', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=150, outf='seg', workers=4)
# Random Seed:  5286
# {'Earphone': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 3
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Earphone': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Table' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Table', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  8331
# {'Table': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 3
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Table': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=50  --class_choice='Laptop' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Laptop', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=50, outf='seg', workers=4)
# Random Seed:  7311
# {'Laptop': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 2
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Laptop': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=150  --class_choice='Guitar' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Guitar', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=150, outf='seg', workers=4)
# Random Seed:  4908
# {'Guitar': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 3
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Guitar': 0}
# ...

# %%
 # !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=200  --class_choice='Lamp' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Lamp', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=200, outf='seg', workers=4)
# Random Seed:  9351
# {'Lamp': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Lamp': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=250  --class_choice='Cap' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Cap', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=250, outf='seg', workers=4)
# Random Seed:  1345
# {'Cap': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 2
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Cap': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=150  --class_choice='Motorbike' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Motorbike', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=150, outf='seg', workers=4)
# Random Seed:  6687
# {'Motorbike': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 6
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Motorbike': 0}
# ...

# %%
# !python /content/pointnet.pytorch/utils/train_segmentation.py --dataset /content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0 --nepoch=250  --class_choice='Mug' --feature_transform
# Out:
# Namespace(batchSize=32, class_choice='Mug', dataset='/content/drive/MyDrive/pointnet.pytorch-master/shapenetcore_partanno_segmentation_benchmark_v0', feature_transform=True, model='', nepoch=250, outf='seg', workers=4)
# Random Seed:  5510
# {'Mug': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 2
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'Mug': 0}
# ...
